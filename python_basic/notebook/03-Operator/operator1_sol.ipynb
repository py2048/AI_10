# %% [markdown]
# ### **Hướng dẫn**
#
# Công thức tính diện tích tam giác được cho như sau:**![Image result for
# area triangle
# formula](data:image/png;base64,...)**
#
# Code mẫu:
#
# ``` python
# a = int(input())
# h = int(input())
#
# area = 1/2 * a * h
#
# print("The area of triangle is", area)
# ```
#
# \`\`
